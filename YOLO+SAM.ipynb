# %% [markdown]
# <a href="https://colab.research.google.com/github/SamWise44/Git-Test/blob/YOLO%2BSAM/YOLO%2BSAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/AI_Class/PROJECT_PUB
# !git clone https://github.com/facebookresearch/sam2.git
# %cd sam2
# !pip install -e .

# %cd /content/drive/MyDrive/AI_Class/PROJECT_PUB/sam2/checkpoints
# !chmod +x ./download_ckpts.sh

# !./download_ckpts.sh
# %cd ..
# %cd /content/drive/MyDrive/AI_Class/PROJECT_PUB/sam2
# Out:
# /content/drive/MyDrive/AI_Class/PROJECT_PUB
# Cloning into 'sam2'...
# remote: Enumerating objects: 1070, done.
# remote: Total 1070 (delta 0), reused 0 (delta 0), pack-reused 1070 (from 1)
# Receiving objects: 100% (1070/1070), 128.11 MiB | 15.14 MiB/s, done.
# Resolving deltas: 100% (380/380), done.
# Updating files: 100% (569/569), done.
# /content/drive/MyDrive/AI_Class/PROJECT_PUB/sam2
# Obtaining file:///content/drive/MyDrive/AI_Class/PROJECT_PUB/sam2
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 5.9 MB/s eta 0:00:00
# ...
#   Building editable for SAM-2 (pyproject.toml) ... done
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
import torch
from sam2.build_sam import build_sam2_video_predictor

checkpoint = "./checkpoints/sam2.1_hiera_tiny.pt"
model_cfg = "configs/sam2.1/sam2.1_hiera_t.yaml"
predictor = build_sam2_video_predictor(model_cfg, checkpoint)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3835178795.py in <cell line: 0>()
#       4 checkpoint = "./checkpoints/sam2.1_hiera_tiny.pt"
#       5 model_cfg = "configs/sam2.1/sam2.1_hiera_t.yaml"
# ----> 6 predictor = build_sam2_video_predictor(model_cfg, checkpoint)
#
# /content/drive/MyDrive/AI_Class/PROJECT_PUB/sam2/sam2/build_sam.py in build_sam2_video_predictor(config_file, ckpt_path, device, mode, hydra_overrides_extra, apply_postprocessing, vos_optimized, **kwargs)
#     136     model = instantiate(cfg.model, _recursive_=True)
#     137     _load_checkpoint(model, ckpt_path)
# --> 138     model = model.to(device)
#     139     if mode == "eval":
#     140         model.eval()
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1367                     raise
#    1368
# ...
